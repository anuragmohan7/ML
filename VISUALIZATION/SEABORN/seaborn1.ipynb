# %%
import seaborn as sns
df=sns.load_dataset('tips') #tips is built in dataset inside seaborn for study purpose 
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dtypes #category === object
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# FEATURE SELECTION

#steps...
# 1. CO-RELATION --> it is used to check how numeric columns related to other numeric columns
# 2. CHI-SQUARE TEST ---> it is used to check how object columns related to other object columns

# %%
#co-relation
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# HEAT-MAP   --->  graphical plot of co-relation
sns.heatmap(df.corr(numeric_only=True),fmt='2f',annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# JOINT PLOT  --->   just like scatter plot also it can plot regression line or histogram  withit (only numeric columns)
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg') #kind is used to plot regression line withit (kind='reg','hex')

# %%
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
sns.jointplot(x='size',y='total_bill',data=df,kind='hex')

# %%
# PAIR PLOT --->  it is used to plot all joint plot in a single plot (only numeric column)
sns.pairplot(df,kind='reg')

# %%
sns.pairplot(df,hue='time')  # hue is used to plot pair plot corresponding to an object column

# %%
sns.pairplot(df,hue='smoker')

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# COUNT PLOT ---> it is used to plot count of columns just like values count(), in seaborn it is plot in single step
sns.countplot(x='day',data=df,color='red',hue='smoker')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4820\1905390743.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(x='day',data=df,color='red',hue='smoker')
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df,color='blue',hue='sex')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4820\2838893476.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.countplot(x='time',data=df,color='blue',hue='sex')
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,color='green')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,color='orange')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# BAR CHART
sns.barplot(x='total_bill',y='day',data=df)   #horizontal line represent the average
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
