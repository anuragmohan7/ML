# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
#insights
df['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
chart=df['State'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.bar(chart.index,chart.values)
plt.xlabel('state')
plt.ylabel('count')
plt.title('state - count')
plt.show()

# %%
maxamount=df.groupby('State')['R&D Spend'].max()
maxamount
# Out:
# State
# California    162597.70
# Florida       153441.51
# New York      165349.20
# Name: R&D Spend, dtype: float64

# %%
plt.pie(maxamount.values,labels=maxamount.index,autopct='%0.1f%%')
plt.legend(loc='upper left') 
plt.tight_layout() 
plt.show()

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#input output seperation
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
#regplot
sns.regplot(x=df['R&D Spend'],y=y,line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x=df['Administration'],y=y,line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x=df['Marketing Spend'],y=y,line_kws={'color':'red'})
plt.show()

# %%
#encoding
# next step is encoding the column state, here we use Onehot Encoding,, beacause of the drawback of label encoding hierarcy formation
# onehot encoding expands number of columns

# %%
from sklearn.compose import make_column_transformer #This step is used To convert The column state into different columns
from sklearn.preprocessing import OneHotEncoder
col_trans=make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['State']),remainder='passthrough')
x=col_trans.fit_transform(x)
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
x.shape #now columns are expanded from
# Out:
# (50, 6)

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
df1=pd.DataFrame({'actual value':y_test,'predicted value':y_pred,'difference':y_test-y_pred})
df1
# Out:
#     actual value  predicted value    difference
# 13     134307.35    126187.394115   8119.955885
# 39      81005.76     85788.822595  -4783.062595
# 30      99937.59     99777.028152    160.561848
# 45      64926.08     45706.122383  19219.957617
# 17     125370.37    127062.207228  -1691.837228
# 48      35673.41     51891.838845 -16218.428845
# 26     105733.54    109114.629775  -3381.089775
# 25     107404.34    100600.611237   6803.728763
# 32      97427.84     97953.998747   -526.158747
# 19     122776.86    111730.577068  11046.282932
# 12     141585.52    128818.492007  12767.027993
# 4      166187.94    174195.357726  -8007.417726
# 37      89949.14     93736.285384  -3787.145384
# 8      152211.77    148381.040972   3830.729028
# 3      182901.99    172313.871394  10588.118606

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('mean_absolute_percentage_error = ',mean_absolute_percentage_error(y_test,y_pred))
print('r2_score = ',r2_score(y_test,y_pred))
# Out:
# mean_absolute_percentage_error =  0.08929865344176037
# r2_score =  0.9397108063356006
