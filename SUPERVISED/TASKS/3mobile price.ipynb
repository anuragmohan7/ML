# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df1=pd.read_csv('train.csv')
df2=pd.read_csv('test.csv')
df1
# Out:
#       Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 0               842          2.2   1           7       0.6       188      2
# 1              1021          0.5   0          53       0.7       136      3
# 2               563          0.5   2          41       0.9       145      5
# 3               615          2.5   0          10       0.8       131      6
# 4              1821          1.2  13          44       0.6       141      2
# ...             ...          ...  ..         ...       ...       ...    ...
# 1995            794          0.5   0           2       0.8       106      6
# 1996           1965          2.6   0          39       0.2       187      4
# 1997           1911          0.9   1          36       0.7       108      8
# 1998           1512          0.9   4          46       0.1       145      5
# 1999            510          2.0   5          45       0.9       168      6
#
# ...

# %%
df1.head()
# Out:
#    Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  PC  \
# 0            842          2.2   1           7       0.6       188      2   2
# 1           1021          0.5   0          53       0.7       136      3   6
# 2            563          0.5   2          41       0.9       145      5   6
# 3            615          2.5   0          10       0.8       131      6   9
# 4           1821          1.2  13          44       0.6       141      2  14
#
#    Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  Three_G  \
# 0       20      756  ...         9         7         19       0        0
# 1      905     1988  ...        17         3          7       1        1
# 2     1263     1716  ...        11         2          9       1        1
# 3     1216     1786  ...        16         8         11       0        1
# 4     1208     1212  ...         8         2         15       1        1
#
#    Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
df1.tail()
# Out:
#       Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 1995            794          0.5   0           2       0.8       106      6
# 1996           1965          2.6   0          39       0.2       187      4
# 1997           1911          0.9   1          36       0.7       108      8
# 1998           1512          0.9   4          46       0.1       145      5
# 1999            510          2.0   5          45       0.9       168      6
#
#       PC  Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  \
# 1995  14     1222     1890  ...        13         4         19       1
# 1996   3      915     1965  ...        11        10         16       0
# 1997   3      868     1632  ...         9         1          5       1
# 1998   5      336      670  ...        18        10         19       1
# 1999  16      483      754  ...        19         4          2       1
#
#       Three_G  Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
df1.columns
# Out:
# Index(['Battery_Power', 'Clock_Speed', 'FC', 'Int_Memory', 'Mobile_D',
#        'Mobile_W', 'Cores', 'PC', 'Pixel_H', 'Pixel_W', 'Ram', 'Screen_H',
#        'Screen_W', 'Talk_Time', 'Four_G', 'Three_G', 'Touch_Screen',
#        'Dual_SIM', 'Bluetooth', 'WiFi', 'Price_Range'],
#       dtype='object')

# %%
df1.shape
# Out:
# (2000, 21)

# %%
df1.isna().sum()
# Out:
# Battery_Power    0
# Clock_Speed      0
# FC               0
# Int_Memory       0
# Mobile_D         0
# Mobile_W         0
# Cores            0
# PC               0
# Pixel_H          0
# Pixel_W          0
# Ram              0
# Screen_H         0
# Screen_W         0
# Talk_Time        0
# Four_G           0
# Three_G          0
# Touch_Screen     0
# Dual_SIM         0
# Bluetooth        0
# WiFi             0
# Price_Range      0
# dtype: int64

# %%
df1.dtypes
# Out:
# Battery_Power      int64
# Clock_Speed      float64
# FC                 int64
# Int_Memory         int64
# Mobile_D         float64
# Mobile_W           int64
# Cores              int64
# PC                 int64
# Pixel_H            int64
# Pixel_W            int64
# Ram                int64
# Screen_H           int64
# Screen_W           int64
# Talk_Time          int64
# Four_G             int64
# Three_G            int64
# Touch_Screen       int64
# Dual_SIM           int64
# Bluetooth          int64
# WiFi               int64
# Price_Range        int64
# dtype: object

# %%
plt.figure(figsize=(10,6))
numeric_columns=df1.select_dtypes(include=[np.number]).columns  #np.number means only numeric column needed 
sns.boxplot(data=df1[numeric_columns])
plt.title('box plot of all features')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5) #annot means write values inside cell,fmt .2f means Floating number with two decimal places
plt.title('heatmap')
plt.show()

# %%
df1.dtypes
# Out:
# Battery_Power      int64
# Clock_Speed      float64
# FC                 int64
# Int_Memory         int64
# Mobile_D         float64
# Mobile_W           int64
# Cores              int64
# PC                 int64
# Pixel_H            int64
# Pixel_W            int64
# Ram                int64
# Screen_H           int64
# Screen_W           int64
# Talk_Time          int64
# Four_G             int64
# Three_G            int64
# Touch_Screen       int64
# Dual_SIM           int64
# Bluetooth          int64
# WiFi               int64
# Price_Range        int64
# dtype: object

# %%
df1.drop(['Clock_Speed','Mobile_D','Mobile_W','Cores','Four_G','Touch_Screen'],axis=1,inplace=True)

# %%
df1.shape
# Out:
# (2000, 15)

# %%
df1
# Out:
#       Battery_Power  FC  Int_Memory  PC  Pixel_H  Pixel_W   Ram  Screen_H  \
# 0               842   1           7   2       20      756  2549         9
# 1              1021   0          53   6      905     1988  2631        17
# 2               563   2          41   6     1263     1716  2603        11
# 3               615   0          10   9     1216     1786  2769        16
# 4              1821  13          44  14     1208     1212  1411         8
# ...             ...  ..         ...  ..      ...      ...   ...       ...
# 1995            794   0           2  14     1222     1890   668        13
# 1996           1965   0          39   3      915     1965  2032        11
# 1997           1911   1          36   3      868     1632  3057         9
# 1998           1512   4          46   5      336      670   869        18
# 1999            510   5          45  16      483      754  3919        19
#
#       Screen_W  Talk_Time  Three_G  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
x_train=df1.iloc[:,:-1]
y_train=df1.iloc[:,-1]

# %%
df2.head()
# Out:
#    Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  PC  \
# 0           1043          1.8  14           5       0.1       193      3  16
# 1            841          0.5   4          61       0.8       191      5  12
# 2           1807          2.8   1          27       0.9       186      3   4
# 3           1546          0.5  18          25       0.5        96      8  20
# 4           1434          1.4  11          49       0.5       108      6  18
#
#    Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  Three_G  \
# 0      226     1412  ...        12         7          2       0        0
# 1      746      857  ...         6         0          7       1        1
# 2     1270     1366  ...        17        10         10       0        0
# 3      295     1752  ...        10         0          7       1        1
# 4      749      810  ...        15         8          7       1        1
#
#    Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
df2.tail()
# Out:
#      Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 995           1700          1.9   0          54       0.5       170      7
# 996            609          1.8   0          13       0.9       186      4
# 997           1185          1.4   1           8       0.5        80      1
# 998           1533          0.5   0          50       0.4       171      2
# 999           1270          0.5   4          35       0.1       140      6
#
#      PC  Pixel_H  Pixel_W  ...  Screen_H  Screen_W  Talk_Time  Four_G  \
# 995  17      644      913  ...        14         8         15       1
# 996   2     1152     1632  ...         8         1         19       0
# 997  12      477      825  ...         5         0         14       1
# 998  12       38      832  ...        15        11          6       0
# 999  19      457      608  ...         9         2          3       1
#
#      Three_G  Touch_Screen  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
df2.shape
# Out:
# (1000, 21)

# %%
df2.columns
# Out:
# Index(['Battery_Power', 'Clock_Speed', 'FC', 'Int_Memory', 'Mobile_D',
#        'Mobile_W', 'Cores', 'PC', 'Pixel_H', 'Pixel_W', 'Ram', 'Screen_H',
#        'Screen_W', 'Talk_Time', 'Four_G', 'Three_G', 'Touch_Screen',
#        'Dual_SIM', 'Bluetooth', 'WiFi', 'Price_Range'],
#       dtype='object')

# %%
df2.isna().sum()
# Out:
# Battery_Power    0
# Clock_Speed      0
# FC               0
# Int_Memory       0
# Mobile_D         0
# Mobile_W         0
# Cores            0
# PC               0
# Pixel_H          0
# Pixel_W          0
# Ram              0
# Screen_H         0
# Screen_W         0
# Talk_Time        0
# Four_G           0
# Three_G          0
# Touch_Screen     0
# Dual_SIM         0
# Bluetooth        0
# WiFi             0
# Price_Range      0
# dtype: int64

# %%
df2.dtypes
# Out:
# Battery_Power      int64
# Clock_Speed      float64
# FC                 int64
# Int_Memory         int64
# Mobile_D         float64
# Mobile_W           int64
# Cores              int64
# PC                 int64
# Pixel_H            int64
# Pixel_W            int64
# Ram                int64
# Screen_H           int64
# Screen_W           int64
# Talk_Time          int64
# Four_G             int64
# Three_G            int64
# Touch_Screen       int64
# Dual_SIM           int64
# Bluetooth          int64
# WiFi               int64
# Price_Range        int64
# dtype: object

# %%
df2.drop(['Clock_Speed','Mobile_D','Mobile_W','Cores','Four_G','Touch_Screen'],axis=1,inplace=True)

# %%
df2
# Out:
#      Battery_Power  FC  Int_Memory  PC  Pixel_H  Pixel_W   Ram  Screen_H  \
# 0             1043  14           5  16      226     1412  3476        12
# 1              841   4          61  12      746      857  3895         6
# 2             1807   1          27   4     1270     1366  2396        17
# 3             1546  18          25  20      295     1752  3893        10
# 4             1434  11          49  18      749      810  1773        15
# ..             ...  ..         ...  ..      ...      ...   ...       ...
# 995           1700   0          54  17      644      913  2121        14
# 996            609   0          13   2     1152     1632  1933         8
# 997           1185   1           8  12      477      825  1223         5
# 998           1533   0          50  12       38      832  2509        15
# 999           1270   4          35  19      457      608  2828         9
#
#      Screen_W  Talk_Time  Three_G  Dual_SIM  Bluetooth  WiFi  Price_Range
# ...

# %%
x_test=df2.iloc[:,:-1]
y_test=df2.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('mean_absolute_percentage_error = ',mean_absolute_percentage_error(y_test,y_pred))
print('r2_score = ',r2_score(y_test,y_pred))
# Out:
# mean_absolute_percentage_error =  3301632205562202.0
# r2_score =  -8.41379552083879

# %%
ss=pd.DataFrame({'actual value':y_test,'predicted value':y_pred})
ss
# Out:
#      actual value  predicted value
# 0               1         2.568004
# 1               1         2.914717
# 2               1         2.228801
# 3               0         3.384718
# 4               0         1.203994
# ..            ...              ...
# 995             1         1.685035
# 996             0         1.180113
# 997             0         0.450638
# 998             1         1.720919
# 999             1         1.954281
#
# [1000 rows x 2 columns]
